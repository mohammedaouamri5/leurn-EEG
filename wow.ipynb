# %%
import pandas as pd 
pd.read_csv("FP1/s01_060926_2n.csv").iloc[0][0]
# Out:
# /tmp/ipykernel_12440/3422318361.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pd.read_csv("FP1/s01_060926_2n.csv").iloc[0][0]
# ...
